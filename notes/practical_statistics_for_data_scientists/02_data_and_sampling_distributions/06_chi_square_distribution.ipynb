# %% [markdown]
# # Chi-square Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 import numpy as np
# ----> 2 import matplotlib.pyplot as plt
#       3 import scipy.stats as stats
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
headlines = ["A", "B", "C"]
headline_counts = np.array([14,8,12])
avg = sum(headline_counts) / len(headline_counts)

# %%
chi2_stat, p_value = stats.chisquare(f_obs=headline_counts, f_exp=avg)
print(f"Chi-square statistic: {chi2_stat}")
print(f"P value: {p_value}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 chi2_stat, p_value = stats.chisquare(f_obs=headline_counts, f_exp=avg)
#       2 print(f"Chi-square statistic: {chi2_stat}")
#       3 print(f"P value: {p_value}")
#
# NameError: name 'stats' is not defined

# %% [markdown]
# # Another part

# %%
x = np.linspace(0, 10, 100)
y = stats.chi2.pdf(x, df=2)

plt.plot(x, y)
plt.fill_between(x, y, where=(x > chi2_stat), alpha=0.5, label='P-Value')
plt.axvline(chi2_stat, color='black', linestyle='--', label='Statistic')

plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 x = np.linspace(0, 10, 100)
# ----> 2 y = stats.chi2.pdf(x, df=2)
#       4 plt.plot(x, y)
#       5 plt.fill_between(x, y, where=(x > chi2_stat), alpha=0.5, label='P-Value')
#
# NameError: name 'stats' is not defined
