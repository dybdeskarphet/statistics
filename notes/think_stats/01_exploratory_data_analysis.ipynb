# %% [markdown]
# # Exploratory Data Analysis

# %%
import numpy as np
import pandas as pd
from scipy.constants import pound as POUND

# %%
from statadict import parse_stata_dict

# %%
stata_dict = parse_stata_dict('./data/2002FemPreg.dct')
resp = pd.read_fwf('./data/2002FemPreg.dat', names=stata_dict.names, colspecs=stata_dict.colspecs)
resp
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13588   12571         1        NaN        NaN       NaN       NaN       6.0
# 13589   12571         2        NaN        NaN       NaN       NaN       3.0
# 13590   12571         3        NaN        NaN       NaN       NaN       3.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
#        pregend2  nbrnaliv  multbrth  ...  poverty_i  laborfor_i  religion_i  \
# 0           NaN       1.0       NaN  ...          0           0           0
# 1           NaN       1.0       NaN  ...          0           0           0
# 2           NaN       3.0       5.0  ...          0           0           0
# 3           NaN       1.0       NaN  ...          0           0           0
# 4           NaN       1.0       NaN  ...          0           0           0
# ...         ...       ...       ...  ...        ...         ...         ...
# 13588       NaN       1.0       NaN  ...          0           0           0
# 13589       NaN       NaN       NaN  ...          0           0           0
# 13590       NaN       NaN       NaN  ...          0           0           0
# 13591       NaN       1.0       NaN  ...          0           0           0
# 13592       NaN       1.0       NaN  ...          0           0           0
#
#        metro_i      basewgt  adj_mod_basewgt      finalwgt  secu_p  sest  \
# 0            0  3410.389399      3869.349602   6448.271112       2     9
# 1            0  3410.389399      3869.349602   6448.271112       2     9
# 2            0  7226.301740      8567.549110  12999.542264       2    12
# 3            0  7226.301740      8567.549110  12999.542264       2    12
# 4            0  7226.301740      8567.549110  12999.542264       2    12
# ...        ...          ...              ...           ...     ...   ...
# 13588        0  4670.540953      5795.692880   6269.200989       1    78
# 13589        0  4670.540953      5795.692880   6269.200989       1    78
# 13590        0  4670.540953      5795.692880   6269.200989       1    78
# 13591        0  4670.540953      5795.692880   6269.200989       1    78
# 13592        0  4670.540953      5795.692880   6269.200989       1    78
#
#        cmintvw
# 0         1231
# 1         1231
# 2         1231
# 3         1231
# 4         1231
# ...        ...
# 13588     1227
# 13589     1227
# 13590     1227
# 13591     1227
# 13592     1227
#
# [13593 rows x 243 columns]

# %% [markdown]
# I just want to check if data is corrupted since a lot of rows have `NaN` for howpreg_n

# %%
resp[resp["howpreg_n"].notna()]
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 202       225         1        4.0        1.0       1.0       NaN       NaN
# 283       285         2        9.0        1.0       2.0       NaN       NaN
# 295       292         4        8.0        1.0       2.0       NaN       NaN
# 307       302         2       22.0        1.0       5.0       NaN       NaN
# 453       427         2       29.0        1.0       7.0       NaN       NaN
# ...       ...       ...        ...        ...       ...       ...       ...
# 13425   12407         2       27.0        1.0       6.0       NaN       NaN
# 13440   12415         3        8.0        1.0       2.0       NaN       NaN
# 13441   12416         1       22.0        1.0       5.0       NaN       NaN
# 13530   12517         1       25.0        1.0       6.0       NaN       NaN
# 13577   12565         2       35.0        1.0       8.0       NaN       NaN
#
#        pregend2  nbrnaliv  multbrth  ...  poverty_i  laborfor_i  religion_i  \
# 202         NaN       NaN       NaN  ...          0           0           0
# 283         NaN       NaN       NaN  ...          0           0           0
# 295         NaN       NaN       NaN  ...          0           0           0
# 307         NaN       NaN       NaN  ...          0           0           0
# 453         NaN       NaN       NaN  ...          0           0           0
# ...         ...       ...       ...  ...        ...         ...         ...
# 13425       NaN       NaN       NaN  ...          0           0           0
# 13440       NaN       NaN       NaN  ...          0           0           0
# 13441       NaN       NaN       NaN  ...          0           0           0
# 13530       NaN       NaN       NaN  ...          0           0           0
# 13577       NaN       NaN       NaN  ...          0           0           0
#
#        metro_i      basewgt  adj_mod_basewgt      finalwgt  secu_p  sest  \
# 202          0  2148.748487      2689.603580   3580.669246       1    44
# 283          0  6562.704646      8648.584060  14546.053530       2    65
# 295          0  2817.008202      3357.492213   4365.075626       1    54
# 307          0  4870.737797      5152.472057   8939.539019       1    74
# 453          0  4596.926139      5285.561481   7435.199336       1    30
# ...        ...          ...              ...           ...     ...   ...
# 13425        0  1833.295397      2078.242296   2766.763968       2     2
# 13440        0  2580.625342      3002.831758   5050.462734       2    82
# 13441        0  3454.927434      3723.198051   6459.748618       2    78
# 13530        0  2734.661252      3244.480863   5629.174298       1    69
# 13577        0  3195.641221      3834.241709   6652.409365       1    78
#
#        cmintvw
# 202       1235
# 283       1236
# 295       1234
# 307       1228
# 453       1228
# ...        ...
# 13425     1228
# 13440     1234
# 13441     1233
# 13530     1237
# 13577     1236
#
# [352 rows x 243 columns]

# %% [markdown]
# No, data is not corrupted. Checking the [codebook](https://ftp.cdc.gov/pub/Health_Statistics/NCHS/Dataset_Documentation/NSFG/Cycle6Codebook-Pregnancy.pdf) may help for better resolution.

# %% [markdown]
# Now, let's check the shape of this dataframe.

# %%
resp.shape
# Out:
# (13593, 243)

# %% [markdown]
# It has 243 variables about 13593 pregnancies.

# %% [markdown]
# Let's check the `outcome` variable.

# %%
resp["outcome"].value_counts().sort_index()
# Out:
# outcome
# 1    9148
# 2    1862
# 3     120
# 4    1921
# 5     190
# 6     352
# Name: count, dtype: int64

# %% [markdown]
# `value_counts()` counts the number of different values, useful for counting elements for different categorical variables.

# %%
for i in resp.columns:
    if i.startswith("birth"):
        print(i)
# Out:
# birthwgt_lb
# birthwgt_oz
# birthwgt_lb2
# birthwgt_oz2
# birthwgt_lb3
# birthwgt_oz3
# birthplc
# birthord
# birthord_i

# %% [markdown]
# Also, here are the birth weights.

# %%
resp["birthwgt_lb"].value_counts(dropna=False).sort_index()
# Out:
# birthwgt_lb
# 0.0        8
# 1.0       40
# 2.0       53
# 3.0       98
# 4.0      229
# 5.0      697
# 6.0     2223
# 7.0     3049
# 8.0     1889
# 9.0      623
# 10.0     132
# 11.0      26
# 12.0      10
# 13.0       3
# 14.0       3
# 15.0       1
# 51.0       1
# 97.0       1
# 98.0       1
# 99.0      57
# NaN     4449
# Name: count, dtype: int64

# %% [markdown]
# As we can see, there are weights far above what a baby could possibly weigh. We are going to replace those values with `NaN`.

# %%
resp["birthwgt_lb"] = resp["birthwgt_lb"].replace([15,51,97,98,99], np.nan)

# %% [markdown]
# Now it is clearer.

# %%
resp["birthwgt_lb"].value_counts(dropna=False).sort_index()
# Out:
# birthwgt_lb
# 0.0        8
# 1.0       40
# 2.0       53
# 3.0       98
# 4.0      229
# 5.0      697
# 6.0     2223
# 7.0     3049
# 8.0     1889
# 9.0      623
# 10.0     132
# 11.0      26
# 12.0      10
# 13.0       3
# 14.0       3
# NaN     4510
# Name: count, dtype: int64

# %% [markdown]
# Now, let's look at the average age of women for the end of birth.

# %%
for i in resp.columns:
    if i.startswith("age"):
        print(i)
# Out:
# ageatend
# ageqtnur_n
# ageqtnur_p
# ageqtnur
# ageqtnur_n2
# ageqtnur_p2
# ageqtnur2
# ageqtnur_n3
# ageqtnur_p3
# ageqtnur3
# agepreg
# agecon
# ager
# agescrn
# agepreg_i
# agecon_i
# ager_i

# %%
resp["agepreg"].mean()
# Out:
# np.float64(2468.8151197039497)

# %% [markdown]
# In this dataset, `agepreg` is stored as centiyear (which is hundredths of a year), it would be eaiser for us if we transformed this column into years.

# %%
resp["agepreg"] /= 100

# %%
resp["agepreg"]
# Out:
# 0        33.16
# 1        39.25
# 2        14.33
# 3        17.83
# 4        18.33
#          ...
# 13588    17.91
# 13589    18.50
# 13590    19.75
# 13591    21.58
# 13592    21.58
# Name: agepreg, Length: 13593, dtype: float64

# %% [markdown]
# Now, let's look at the average of `agepreg`. Mother's age at the end of the pregnancy.

# %%
resp["agepreg"].mean()
# Out:
# np.float64(24.6881511970395)

# %%
resp[['birthwgt_lb', 'birthwgt_oz']]
# Out:
#        birthwgt_lb  birthwgt_oz
# 0              8.0         13.0
# 1              7.0         14.0
# 2              9.0          2.0
# 3              7.0          0.0
# 4              6.0          3.0
# ...            ...          ...
# 13588          6.0          3.0
# 13589          NaN          NaN
# 13590          NaN          NaN
# 13591          7.0          8.0
# 13592          7.0          8.0
#
# [13593 rows x 2 columns]

# %% [markdown]
# Coming back to weights, we see that birth weight is separated to pounds and ounces, we will combine them in `totalwgt_lb`.

# %%
resp["totalwgt_lb"] = resp["birthwgt_lb"] + resp["birthwgt_oz"] / 16.0
resp[['totalwgt_lb','birthwgt_lb', 'birthwgt_oz']]
# Out:
# /tmp/ipykernel_738196/781844691.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   resp["totalwgt_lb"] = resp["birthwgt_lb"] + resp["birthwgt_oz"] / 16.0
#        totalwgt_lb  birthwgt_lb  birthwgt_oz
# 0           8.8125          8.0         13.0
# 1           7.8750          7.0         14.0
# 2           9.1250          9.0          2.0
# 3           7.0000          7.0          0.0
# 4           6.1875          6.0          3.0
# ...            ...          ...          ...
# 13588       6.1875          6.0          3.0
# 13589          NaN          NaN          NaN
# 13590          NaN          NaN          NaN
# 13591       7.5000          7.0          8.0
# 13592       7.5000          7.0          8.0
#
# [13593 rows x 3 columns]

# %% [markdown]
# Also, who uses imperal system anyway? Let's convert this to kilograms.

# %%
resp["totalwgt_kg"] = resp["totalwgt_lb"] * POUND
resp["totalwgt_kg"]
# Out:
# /tmp/ipykernel_738196/542290660.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   resp["totalwgt_kg"] = resp["totalwgt_lb"] * POUND
# 0        3.997283
# 1        3.572040
# 2        4.139030
# 3        3.175147
# 4        2.806603
#            ...
# 13588    2.806603
# 13589         NaN
# 13590         NaN
# 13591    3.401943
# 13592    3.401943
# Name: totalwgt_kg, Length: 13593, dtype: float64

# %% [markdown]
# We are getting "highly fragmented dataframe" warning, let's fix it.

# %%
resp = resp.copy()
resp
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 0           1         1        NaN        NaN       NaN       NaN       6.0
# 1           1         2        NaN        NaN       NaN       NaN       6.0
# 2           2         1        NaN        NaN       NaN       NaN       5.0
# 3           2         2        NaN        NaN       NaN       NaN       6.0
# 4           2         3        NaN        NaN       NaN       NaN       6.0
# ...       ...       ...        ...        ...       ...       ...       ...
# 13588   12571         1        NaN        NaN       NaN       NaN       6.0
# 13589   12571         2        NaN        NaN       NaN       NaN       3.0
# 13590   12571         3        NaN        NaN       NaN       NaN       3.0
# 13591   12571         4        NaN        NaN       NaN       NaN       6.0
# 13592   12571         5        NaN        NaN       NaN       NaN       6.0
#
#        pregend2  nbrnaliv  multbrth  ...  religion_i  metro_i      basewgt  \
# 0           NaN       1.0       NaN  ...           0        0  3410.389399
# 1           NaN       1.0       NaN  ...           0        0  3410.389399
# 2           NaN       3.0       5.0  ...           0        0  7226.301740
# 3           NaN       1.0       NaN  ...           0        0  7226.301740
# 4           NaN       1.0       NaN  ...           0        0  7226.301740
# ...         ...       ...       ...  ...         ...      ...          ...
# 13588       NaN       1.0       NaN  ...           0        0  4670.540953
# 13589       NaN       NaN       NaN  ...           0        0  4670.540953
# 13590       NaN       NaN       NaN  ...           0        0  4670.540953
# 13591       NaN       1.0       NaN  ...           0        0  4670.540953
# 13592       NaN       1.0       NaN  ...           0        0  4670.540953
#
#        adj_mod_basewgt      finalwgt  secu_p  sest  cmintvw  totalwgt_lb  \
# 0          3869.349602   6448.271112       2     9     1231       8.8125
# 1          3869.349602   6448.271112       2     9     1231       7.8750
# 2          8567.549110  12999.542264       2    12     1231       9.1250
# 3          8567.549110  12999.542264       2    12     1231       7.0000
# 4          8567.549110  12999.542264       2    12     1231       6.1875
# ...                ...           ...     ...   ...      ...          ...
# 13588      5795.692880   6269.200989       1    78     1227       6.1875
# 13589      5795.692880   6269.200989       1    78     1227          NaN
# 13590      5795.692880   6269.200989       1    78     1227          NaN
# 13591      5795.692880   6269.200989       1    78     1227       7.5000
# 13592      5795.692880   6269.200989       1    78     1227       7.5000
#
#        totalwgt_kg
# 0         3.997283
# 1         3.572040
# 2         4.139030
# 3         3.175147
# 4         2.806603
# ...            ...
# 13588     2.806603
# 13589          NaN
# 13590          NaN
# 13591     3.401943
# 13592     3.401943
#
# [13593 rows x 245 columns]

# %% [markdown]
# For now, we fixed it. But using dictionaries, creating a data frame with it, then concatenating them in one of those data frames is much more efficient when there are innumerous amount of variables.

# %% [markdown]
# Now we can summarize the statistics.

# %%
weights = resp["totalwgt_kg"]
n = weights.count()
weights
# Out:
# 0        3.997283
# 1        3.572040
# 2        4.139030
# 3        3.175147
# 4        2.806603
#            ...
# 13588    2.806603
# 13589         NaN
# 13590         NaN
# 13591    3.401943
# 13592    3.401943
# Name: totalwgt_kg, Length: 13593, dtype: float64

# %%
print(weights.sum() / n)
print(weights.mean())
mean = weights.mean()
# Out:
# 3.3079302256167424
# 3.3079302256167424

# %% [markdown]
# $$
# SS = \sum (x_i - \hat{x})^2
# $$

# %%
squared_deviations = (weights - mean) ** 2
squared_deviations
# Out:
# 0        0.475207
# 1        0.069754
# 2        0.690727
# 3        0.017631
# 4        0.251329
#            ...
# 13588    0.251329
# 13589         NaN
# 13590         NaN
# 13591    0.008838
# 13592    0.008838
# Name: totalwgt_kg, Length: 13593, dtype: float64

# %% [markdown]
# $$
# s^2 = \frac{SS}{n-1}
# $$

# %%
print(squared_deviations.sum() / (n - 1))
var = weights.var(ddof=1)
# Out:
# 0.43871134313956867

# %% [markdown]
# $$
# s = \sqrt{\frac{SS}{n-1}}
# $$

# %%
print(np.sqrt(var))
std = weights.std(ddof=1)
print(std)
# Out:
# 0.662352884148298
# 0.662352884148298

# %% [markdown]
# Informally, values that are one or two SDs from the mean are common.
#
# There are number of ways to interpret this data. But for this exercise, we are going to analyse `caseid` 10229

# %%
subset = resp[resp["caseid"] == 10229]
subset["outcome"]
# Out:
# 11093    4
# 11094    4
# 11095    4
# 11096    4
# 11097    4
# 11098    4
# 11099    1
# Name: outcome, dtype: int64

# %% [markdown]
# `1` indicates a live birth, `4` indicates a miscarriage. If we consider this data with empathy, it is natural to be moved by the story it tells.

# %% [markdown]
# Finally, let's do some practice.

# %%
resp["birthord"].value_counts().sort_index()
# Out:
# birthord
# 1.0     4413
# 2.0     2874
# 3.0     1234
# 4.0      421
# 5.0      126
# 6.0       50
# 7.0       20
# 8.0        7
# 9.0        2
# 10.0       1
# Name: count, dtype: int64

# %%
resp[resp["caseid"] == 2298]
# Out:
#       caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 2610    2298         1        NaN        NaN       NaN       NaN       6.0
# 2611    2298         2        NaN        NaN       NaN       NaN       6.0
# 2612    2298         3        NaN        NaN       NaN       NaN       6.0
# 2613    2298         4        NaN        NaN       NaN       NaN       6.0
#
#       pregend2  nbrnaliv  multbrth  ...  religion_i  metro_i      basewgt  \
# 2610       NaN       1.0       NaN  ...           0        0  3247.916977
# 2611       NaN       1.0       NaN  ...           0        0  3247.916977
# 2612       NaN       1.0       NaN  ...           0        0  3247.916977
# 2613       NaN       1.0       NaN  ...           0        0  3247.916977
#
#       adj_mod_basewgt     finalwgt  secu_p  sest  cmintvw  totalwgt_lb  \
# 2610      5123.759559  5556.717241       2    18     1234       6.8750
# 2611      5123.759559  5556.717241       2    18     1234       5.5000
# 2612      5123.759559  5556.717241       2    18     1234       4.1875
# 2613      5123.759559  5556.717241       2    18     1234       6.8750
#
#       totalwgt_kg
# 2610     3.118448
# 2611     2.494758
# 2612     1.899418
# 2613     3.118448
#
# [4 rows x 245 columns]

# %%
resp[(resp["caseid"] == 5013) & (resp["pregordr"] == 1)]["totalwgt_kg"]
# Out:
# 5516    3.345244
# Name: totalwgt_kg, dtype: float64

# %%
resp.to_csv("./data/2002FemPreg_after_01.csv")

# %% [markdown]
# ## Glossary from the resource
#
# - **anecdotal evidence:** Data collected informally from a small number of individual cases, often without systematic sampling.
# - **cross-sectional study:** A study that collects data from a representative sample of a population at a single point or interval in time.
# - **cycle:** One data-collection interval in a study that collects data at multiple intervals in time.
# - **population:** The entire group of individuals or items that is the subject of a study.
# - **sample:** A subset of a population, often chosen at random.
# - **respondents:** People who participate in a survey and respond to questions.
# - **representative:** A sample is representative if it is similar to the population in ways that are important for the purposes of the study.
# - **stratified:** A sample is stratified if it deliberately oversamples some groups, usually to make sure that enough members are included to support valid conclusions.
# - **oversampled:** A group is oversampled if its members have a higher chance of appearing in a sample.
# - **variable:** In survey data, a variable is a collection of responses to questions or values computed from responses.
# - **codebook:** A document that describes the variables in a dataset, and provides other information about the data.
# - **recode:** A variable that is computed based on other variables in a dataset.
# - **raw data:** Data that has not been processed after collection.
# - **data cleaning:** A process for identifying and correcting errors in a dataset, dealing with missing values, and computing recodes.
# - **statistic:** A value that describes or summarizes a property of a sample.
# - **standard deviation:** A statistic that quantifies the spread of data around the mean.
